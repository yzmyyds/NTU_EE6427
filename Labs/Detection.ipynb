# %%
import numpy as np
from ultralytics import YOLO
import cv2

_ = np.array([0])  # 强制初始化 numpy

model = YOLO("yolov8n.pt")
results = model("Images/bus.jpg")
annotated_frame = results[0].plot()
cv2.imshow("YOLO Detection", annotated_frame)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 8
#       5 _ = np.array([0])  # 强制初始化 numpy
#       7 model = YOLO("yolov8n.pt")
# ----> 8 results = model("Images/bus.jpg")
#       9 annotated_frame = results[0].plot()
#      10 cv2.imshow("YOLO Detection", annotated_frame)
#
# File ~/opt/miniconda3/envs/Research/lib/python3.11/site-packages/ultralytics/engine/model.py:187, in Model.__call__(self, source, stream, **kwargs)
#     158 def __call__(
#     159     self,
#     160     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     161     stream: bool = False,
#     162     **kwargs: Any,
#     163 ) -> list:
#     164     """
#     165     Alias for the predict method, enabling the model instance to be callable for predictions.
#     166
#    (...)    185         ...     print(f"Detected {len(r)} objects in image")
# ...
